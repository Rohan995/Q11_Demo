# %%
import urllib
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %%
resource = urllib.urlopen("https://assets.myntassets.com/h_640,q_90,w_480/v1/assets/images/2354027/2018/1/16/11516097831111-MsTaken-Women-Navy-Blue-Striped-Top-4731516097830960-1.jpg")
output = open("image.jpg","wb")
output.write(resource.read())
output.close()
img = Image.open('image.jpg')
width, height = img.size
print ("width:")
print (width)
print ("height:")
print (height)
# Out:
# width:
# 480
# height:
# 640

# %%
img=mpimg.imread('image.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
dim = (242,242)
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
plt.imshow(resized)

# %%
cropped = img[60:420, 115:579]
plt.imshow(cropped)
cv2.imwrite("cropped_image.jpg",cropped)
# Out:
# True
